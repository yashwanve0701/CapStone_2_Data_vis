# %% [markdown]
# # **Project Name**    - EDA for Hotel Bookings

# %% [markdown]
# ##### **Project Type**    - Exploratory Data Analysis
#
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This project looked at data from hotels in cities and resorts to see what influences how guests book rooms. We found that people tend to book city hotels more on weekdays, while resorts are busier on weekends. Guests who stay longer or come in larger groups often ask for more special things, like specific room setups or services. This tells us that guests often choose city hotels for work or short trips, while resorts are more popular for longer vacations or trips with families.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/yashwanve0701/CapStone_2_Data_vis.git

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The booking sites facing challenge to optimizing hotel bookings and various factors influence the decision for both customer and hotel management. To address this challenge i aimed to explore and analyze a hotel booking dataset.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Optimize pricing and promotions based on booking trends.
#
# Customizing services to enhance guest satisfaction and loyalty.
#
# Streamline operations based on stay length and demand patterns.
#
# Develop accurate demand forecasts for proactive management.
#
# Personalize marketing campaigns to target specific guest demographics.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
ds= pd.read_csv("/content/Hotel Bookings.csv")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
ds.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
ds.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
ds.shape
# Out:
# (119390, 32)

# %%
ds.size
# Out:
# 3820480

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
ds.duplicated().value_counts()  # True means the Duplicate values
# Out:
# False    87396
# True     31994
# Name: count, dtype: int64

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
ds.isnull()
# Out:
#         hotel  is_canceled  lead_time  arrival_date_year  arrival_date_month  \
# 0       False        False      False              False               False
# 1       False        False      False              False               False
# 2       False        False      False              False               False
# 3       False        False      False              False               False
# 4       False        False      False              False               False
# ...       ...          ...        ...                ...                 ...
# 119385  False        False      False              False               False
# 119386  False        False      False              False               False
# 119387  False        False      False              False               False
# 119388  False        False      False              False               False
# 119389  False        False      False              False               False
#
# ...

# %%
ds.isnull().sum() # calculated the null values of each group
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# Visualizing the missing values
missing_value=ds.isnull()
sns.heatmap(missing_value)
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# * Why i use this plot ?
#
#   I use this Heatmap because it provides a quick and intutive way to identiy area with missing data.Lighter color indicates the missing values.
#
# * What insights i got ?
#
#   Insights got from the plot is that company column has so many missing or nan value and deposit_tye also having the missing value in greater percentage, also having some other columns which having very less missing value.
#
# * positive or negative impact , what know about the dataset?
#
#   This insight will give us positive impact that company column is not necessary as it is having only few values and other ccolumn need to replace the null value with some values with mean,median or mode.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
ds.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe
ds.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# From the variables i identify that in dataset most of the variable in the integer and some are in the object.
#
# While performing the describe method on the dataset got more insight about the integer datatype variable like- mean, minium value , how many value of 25 percent, 50 and 75 respectively values etc.
#
# Also there are date variable which need to convert to date time datatype for example i convert the object datatype column to the datetime datatype below cells.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
# Check Unique Values for each variable.
print("Hotel -> ",ds.hotel.unique())
print("arival_date_month -> ",ds.arrival_date_month.unique())
print("meal -> ",ds.meal.unique())
print("country -> ",ds.country.unique())
print("assigned_room_type -> ",ds.assigned_room_type.unique())
print("reserved_room_type -> ",ds.reserved_room_type.unique())
print("distribution_channel-> ",ds.distribution_channel.unique())
print("deposit_type -> ",ds.deposit_type.unique())
print("customer_type -> ",ds.customer_type.unique())
print("reservation_status -> ",ds.reserved_room_type.unique())

# As we can see the unique value mostly for categorical variable so i performend the unique value function on the categorical variable or object.
# Out:
# Hotel ->  ['Resort Hotel' 'City Hotel']
# arival_date_month ->  ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# meal ->  ['BB' 'FB' 'HB' 'SC' 'Undefined']
# country ->  ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
#  'KWT' 'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN'
#  'SYC' 'AZE' 'BHR' 'NZL' 'THA' 'DOM' 'MKD' 'MYS' 'ARM' 'JPN' 'LKA' 'CUB'
#  'CMR' 'BIH' 'MUS' 'COM' 'SUR' 'UGA' 'BGR' 'CIV' 'JOR' 'SYR' 'SGP' 'BDI'
#  'SAU' 'VNM' 'PLW' 'QAT' 'EGY' 'PER' 'MLT' 'MWI' 'ECU' 'MDG' 'ISL' 'UZB'
# ...

# %%
(ds.is_canceled == 1).value_counts()
# Out:
# is_canceled
# False    75166
# True     44224
# Name: count, dtype: int64

# %%
print(ds["is_canceled"].unique())# as 0 and 1 that means 0 is not canceled and 1 is for canceled.
# Out:
# [0 1]

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# %%
# As reservation_status_date column is in object so it should be convert in date_time variable
print(ds["reservation_status_date"].head(1)) # to know the order to date time variable
ds["reservation_status_date"]=pd.to_datetime(ds["reservation_status_date"])
# converted to datetime
print(ds["reservation_status_date"].head(1))
# Out:
# 0    2015-07-01
# Name: reservation_status_date, dtype: object
# 0   2015-07-01
# Name: reservation_status_date, dtype: datetime64[ns]

# %%
# Now need to remove the company column as not sufficient data is given for that
ds=ds.drop("company",axis=1)
ds.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# before removing duplicates
ds.shape
# Out:
# (119390, 31)

# %%
# need to remove duplicate rows
ds=ds.drop_duplicates()

# %%
#after removing duplicates
ds.shape
# Out:
# (87389, 31)

# %%
# to add values in null values of columns
mod=ds.country.mode()
print(mod)
ds=ds.fillna(mod)
# Out:
# 0    PRT
# Name: country, dtype: object

# %%
# now agent column as agent column is float type we will use mean in this
mea=ds.agent.mean()
ds=ds.fillna(mea)

# %%
# Perform label encoding on the 'Hotel' column
label_encoder = LabelEncoder()
ds['Hotel'] = label_encoder.fit_transform(ds['hotel'])

# %%
ds.Hotel.head()
# Resort Hotel - 1
# City Hotel = 0
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Hotel, dtype: int64

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# * **Data Manipulation** done by me is to remove unwanted columns which are not have enough data by which i am not able to know more about the column.
# Also i removed the duplicate rows.
#
#   Then I fill the columns which are having null values and which are important columns so cannot remove those coloumn thats why i use fillna function to fill the null values, using mean for numbric data and mode for categorical data.
#
#   Also convert the object variable to the datetime variable which will help to find accurate detail in form of date.
#
# * **Insights** I found that in country column most of the visiters are of PRT i.e Portugal. And there are many agent in agent column.So many duplicate rows.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
# Univariate Analysis

sns.histplot(data=ds, x='lead_time', bins=30)
plt.title('Distribution of Lead Time')
plt.xlabel('Lead Time (days)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The histogram is chosen for univariate analysis, specifically for understanding the distribution of the variable 'lead_time.' Histograms are useful for visualizing the frequency distribution of a continuous variable and identifying patterns.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  Distribution is skewed to the left, it implies more instances with shorter lead times.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The distribution is concentrated towards shorter lead times, it might suggest efficient processes, quick response times, and potential for faster customer service.
#
# If there is a significant concentration at the extreme left (very short lead times), it might indicate rushed processes that could lead to errors or quality issues, negatively impacting customer satisfaction.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
# Bivariate Analysis
sns.boxplot(data=ds, x='is_canceled', y='stays_in_weekend_nights')
plt.title('Relationship between Stays in Weekend Nights and Cancellation')
plt.xlabel('Is Canceled')
plt.ylabel('Stays in Weekend Nights')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A boxplot is chosen for bivariate analysis to understand the relationship between the categorical variable 'is_canceled' and the numerical variable 'stays_in_weekend_nights.Boxplots are useful for visualizing the distribution of a numerical variable across different categories, providing insights into central tendency, spread, and potential outliers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Outliers: Points beyond the whiskers may indicate potential outliers.
# Median Comparison: Comparing the medians of the two boxplots gives an idea of the central tendency of 'stays_in_weekend_nights' for canceled and non-canceled reservations.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# If there is a clear difference in median values between canceled and non-canceled reservations, it could indicate that 'stays_in_weekend_nights' is a significant factor in predicting cancellations. This insight can be used to optimize pricing, promotions, or other factors related to weekend stays to reduce cancellations.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
# Univariate Analysis
plt.figure(figsize=(8, 8))
ds['reservation_status'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Reservation Status')
plt.ylabel('')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart is chosen for univariate analysis to visualize the distribution of the categorical variable 'reservation_status.' Pie charts are effective for displaying parts of a whole, making it easy to see the proportion of each category relative to the total.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the proportion of reservations in different states, such as 'Canceled,' 'Checked-In,' or 'No-Show.'
# Dominant Category: The largest slice of the pie indicates the most prevalent reservation status.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Understanding the distribution of reservation statuses is crucial for managing and optimizing hotel operations. For example, if a significant portion of reservations is 'Canceled,' it may signal an opportunity to improve the booking process, enhance communication with customers, or implement policies to reduce cancellations.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
# Univariate Analysis
sns.countplot(data=ds, x='arrival_date_month', order=['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'])
plt.title('Number of Bookings by Month')
plt.xlabel('Arrival Date Month')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A countplot using Seaborn is chosen for univariate analysis to visualize the distribution of the categorical variable 'arrival_date_month.' Countplots are effective for displaying the frequency of each category in a categorical variable.

# %% [markdown]
# **2**. What is/are the insight(s) found from the chart?

# %% [markdown]
# Booking Patterns: Identify which months have higher or lower booking frequencies.
# Seasonality: Check if there are specific months that consistently have more bookings, potentially indicating seasonal trends.
# Variability: Observe if there are significant variations in booking numbers between months

# %% [markdown]
# **3**. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Understanding booking patterns by month can help in optimizing marketing strategies, pricing, and resource allocation. For instance, if there is a peak in bookings during certain months, the hotel can focus marketing efforts and promotions during those periods.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
# Bivariate Analysis
sns.scatterplot(data=ds, x='lead_time', y='adr', hue='is_canceled', alpha=0.5)
plt.title('Scatter Plot of Lead Time vs. Average Daily Rate (ADR)')
plt.xlabel('Lead Time (days)')
plt.ylabel('ADR')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot with points colored by the 'is_canceled' variable is chosen for bivariate analysis. This type of plot is effective for visualizing the relationship between two numerical variables ('lead_time' and 'adr') and how cancellations are distributed within that relationship.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Lead Time vs. ADR Relationship: Observe how lead time and ADR are distributed and if there is any discernible pattern or correlation.
# Cancellation Status: The hue parameter differentiates between canceled and non-canceled reservations, allowing you to see if cancellations follow a particular trend in the scatter plot.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# There is a clear pattern in the scatter plot indicating that longer lead times are associated with higher ADR for canceled reservations, it may provide insights for pricing strategies or marketing efforts targeting customers with longer lead times.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
# Univariate Ananlysis
ds['customer_type'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title('Distribution of Customer Types')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart is chosen for univariate analysis to visualize the distribution of the categorical variable 'customer_type.' Pie charts are effective for displaying parts of a whole, making it easy to see the proportion of each category relative to the total.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Customer Type Proportions: The chart shows the percentage distribution of different customer types such as 'Transient,' 'Contract,' 'Group,' or 'Transient-Party.'

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Understanding the distribution of customer types is essential for tailoring marketing strategies, service offerings, and communication to different customer segments

# %% [markdown]
# #### Chart - 7

# %%
total_counts = ds[['adults', 'children', 'babies']].sum()

# Plotting
total_counts.plot(kind='bar', stacked=True)
# Out:
# <Axes: >

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a simple bar chart to visualize the total number of adults, children, and babies in the dataset because it effectively conveys the cumulative quantities of these categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Total Counts Comparison:
# We can see the overall number of adults, children, and babies in the dataset.
# This comparison highlights which group (adults, children, or babies) constitutes the majority of the bookings.
#
# Customer Demographics:
#
# The chart can provide a rough estimate of the typical composition of bookings (e.g., predominantly adults, fewer children and babies).
# Understanding these demographics can help tailor marketing strategies and service offerings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# By understanding the dominant customer demographics, hotels can allocate resources more efficiently. adults are the majority, the hotel can ensure more amenities and services tailored to adults, such as business facilities, gym access, and dining options.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
# Univariate Analysis
plt.figure(figsize=(8, 6))
sns.countplot(data=ds, x='is_repeated_guest')
plt.title('Number of Bookings for Repeated Guests')
plt.xlabel('Is Repeated Guest')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A count plot is chosen for univariate analysis to visualize the distribution of the binary categorical variable 'is_repeated_guest.' Count plots are effective for displaying the frequency of each category in a categorical variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Booking Frequency for Repeated Guests: Observe how many bookings are made by guests who have previously stayed at the hotel.
# Proportion of Repeated Guests: Assess the proportion of bookings made by repeated guests compared to first-time guests.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# If the count plot shows a significant number of bookings by repeated guests, it indicates customer loyalty and satisfaction, which can be leveraged for targeted marketing and loyalty programs.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
# Univariate Analysis
sns.countplot(data=ds, x='deposit_type')
plt.title('Number of Bookings by Deposit Type')
plt.xlabel('Deposit Type')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A count plot is chosen for univariate analysis to visualize the distribution of the categorical variable 'deposit_type.' Count plots are effective for displaying the frequency of each category in a categorical variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Booking Distribution by Deposit Type: Observe how many bookings fall into each deposit type category, such as 'No Deposit,' 'Non-Refundable,' or 'Refundable.'
# Prevalence of Deposit Types: Identify the most common deposit type used by guests during the booking process.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#   If the count plot shows that a significant number of bookings are made without a deposit ('No Deposit'), it might indicate a guest-friendly policy that encourages more bookings. This insight can be used to maintain or adjust deposit policies to attract more customers.
#   Understanding the prevalence of different deposit types can guide marketing efforts and promotions, especially if certain deposit types are associated with higher booking numbers.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
plt.figure(figsize=(10, 6))
sns.barplot(data=ds, x='required_car_parking_spaces', y='is_canceled')
plt.title('Cancellation Rate Based on Required Car Parking Spaces')
plt.xlabel('Required Car Parking Spaces')
plt.ylabel('Cancellation Rate')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  bar plot is chosen for bivariate analysis to visualize the cancellation rate based on the number of required car parking spaces. Bar plots are effective for comparing the mean or count of a variable across different categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#   Cancellation Rate Comparison: Observe how the cancellation rate varies across different categories of required car parking spaces.
#   Effect of Car Parking Spaces: Determine if there is a trend indicating that reservations with a certain number of required car parking spaces have a higher or lower cancellation rate.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# If the bar plot shows a lower cancellation rate for reservations with a higher number of required car parking spaces, it might suggest that guests who require parking spaces are more committed to their bookings. This insight can be used to optimize pricing strategies or marketing efforts targeting such guests.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
# Bivariate Analysis
plt.figure(figsize=(10, 6))
sns.barplot(data=ds, x='distribution_channel', y='total_of_special_requests', ci=None)
plt.title('Average Special Requests by Distribution Channel')
plt.xlabel('Distribution Channel')
plt.ylabel('Average Total Special Requests')
plt.show()
# Out:
# <ipython-input-38-da443234001d>:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=ds, x='distribution_channel', y='total_of_special_requests', ci=None)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar plot is chosen for bivariate analysis to visualize the average number of special requests based on different distribution channels. Bar plots are effective for comparing the mean of a variable across different categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#   Comparison of Average Special Requests: Observe how the average number of special requests varies across different distribution channels.
#   Effect of Distribution Channels: Determine if there is a trend indicating that certain distribution channels are associated with a higher or lower average number of special requests.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# If the bar plot shows that a specific distribution channel is associated with a higher average number of special requests, it might suggest that customers using that channel have unique needs or preferences. This insight can be used to tailor services, marketing, or promotions to meet those needs and enhance customer satisfaction.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
# Bivariate Analysis
plt.figure(figsize=(12, 8))
sns.boxenplot(data=ds, x='arrival_date_year', y='lead_time', hue='is_canceled')
plt.title('Boxen Plot of Arrival Year vs. Lead Time')
plt.xlabel('Arrival Year')
plt.ylabel('Lead Time (days)')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  A boxen plot is suitable for showing the distribution of a numerical variable (lead time in this case) across categories (arrival years), and it allows for the comparison of these distributions with respect to cancellation status.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The boxen plot provides insights into how lead time varies across different years of arrival, considering whether reservations were canceled or not. It allows you to observe the central tendency, spread, and potential outliers in lead time for each arrival year.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights gained from this analysis can be beneficial for business decision-making. Understanding how lead time varies over different years and its relationship with cancellation status can inform strategies related to reservation management and resource allocation.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
# univariate Analysis
plt.figure(figsize=(10, 6))
sns.histplot(data=ds, x='booking_changes', bins=20, kde=True)
plt.title('Distribution of Booking Changes')
plt.xlabel('Booking Changes')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The chosen chart is a histogram that illustrates the distribution of the variable 'booking_changes.' A histogram is suitable for displaying the frequency distribution of a single numerical variable, providing insights into the patterns and concentration of values within a specified range.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The histogram reveals the distribution of booking changes, showcasing the frequency of different levels of changes made to bookings. The shape of the distribution, along with the central tendency and spread, can be observed.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Understanding the distribution of booking changes may provide insights into customer behavior, preferences, or potential areas for improvement in the booking process. Businesses can use this information to refine their policies, enhance customer satisfaction, and optimize operational processes related to booking changes, which could contribute to a positive impact on customer experience and overall business efficiency.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
ds.drop('hotel', axis=1, inplace=True)

# %%
# Correlation Heatmap visualization code
numeric_cols = ds.select_dtypes(include='number')
corr_matrix = numeric_cols.corr()

# Plot the correlation heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap of Numeric Columns')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This type of visualization is effective for exploring the relationships between numerical variables in a dataset. By using colors to represent the strength and direction of correlations, the heatmap allows for a quick and intuitive understanding of how variables are related to each other.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The color intensity and the annotated correlation coefficients indicate the strength and direction of these relationships. Positive correlations are represented by warmer colors, while negative correlations are represented by cooler colors. This visualization helps identify which variables are strongly correlated, moderately correlated, or not correlated at all.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
sns.pairplot(ds[['stays_in_week_nights', 'stays_in_weekend_nights', 'total_of_special_requests']])
plt.suptitle('Pairplot of Stays in Week Nights, Stays in Weekend Nights, and Total Special Requests')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The chosen chart is a pair plot that visualizes the relationships between the variables 'stays_in_week_nights,' 'stays_in_weekend_nights,' and 'total_of_special_requests.' A pair plot is effective for simultaneously exploring the distributions and pairwise relationships between multiple numerical variables. It allows for a quick overview of potential patterns and correlations within the selected variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The pair plot provides insights into the relationships between te specified variables. Diagonal subplots display the distrubution of each variable individually, while the off-diagonal subplots show scatter plots, allowing you to observe the pairwise relationships. This visualization can help identify patterns such as clusters, trends, or outliers in the data. Insight is that i explore how the total number of special requests relates to the stays in week nights and weekend nights.

# %% [markdown]
# ###Chart 16

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=ds, x='market_segment', hue='is_canceled')
plt.title('Booking Status by Market Segment')
plt.xlabel('Market Segment')
plt.ylabel('Count')
plt.legend(title='Booking Status', labels=[ 'Not Canceled','Canceled'])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
# I chose a count plot with the market segment on the x-axis and the booking status (canceled vs. not canceled) as the hue because it clearly shows the distribution of bookings across different market segments and how cancellations vary among them. This type of chart is useful for categorical data and allows us to easily compare the counts within each category.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
# The chart reveals which market segments have the highest and lowest number of cancellations. For instance,"Online TA" has a significantly higher number of cancellations compared to other segments, it might indicate a trend that needs further investigation. Conversely, segments with fewer cancellations might be considered more stable or reliable.

# %% [markdown]
# ###Chart - 17

# %%
yearly_bookings = ds.groupby('arrival_date_year').size()

# Plotting
plt.figure(figsize=(14, 6))
yearly_bookings.plot(kind='bar', color='skyblue')
plt.title('Yearly Booking Trends')
plt.xlabel('Year')
plt.ylabel('Number of Bookings')
plt.grid(axis='y')  # Adding grid lines only along the y-axis
plt.xticks(rotation=45)  # Rotating x-axis labels for better readability if needed
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
# I chose a bar chart to display the yearly booking trends because it effectively shows the total number of bookings per year. This type of chart is ideal for comparing categorical data (years in this case) and easily highlights trends over time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
# The chart reveals the booking trends over the years, showing which years had the highest and lowest number of bookings. This can help identify any growth patterns, declines, or anomalies in the booking data, providing valuable insights for forecasting and strategic planning.

# %% [markdown]
# ###Chart - 18

# %%
ds.is_canceled.value_counts()
# Out:
# is_canceled
# 0    63364
# 1    24025
# Name: count, dtype: int64

# %%
yearly_cancelled_bookings = ds.groupby(['arrival_date_year', 'is_canceled']).size().unstack(fill_value=0)

# Plotting
plt.figure(figsize=(14, 6))
yearly_cancelled_bookings.plot(kind='bar', stacked=True, color=['skyblue', 'salmon'])
plt.title('Yearly Booking and Cancellation Trends')
plt.xlabel('Year')
plt.ylabel('Number of Bookings')
plt.grid(axis='y')  # Adding grid lines only along the y-axis
plt.xticks(rotation=0)  # Rotating x-axis labels if needed
plt.legend([ 'Not Cancelled','Cancelled'], loc='upper left')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
# I chose a stacked bar chart to display the yearly booking and cancellation trends because it clearly shows the total number of bookings each year and how many of those were canceled. This chart type allows for a direct comparison between canceled and non-canceled bookings within each year, providing a comprehensive view of booking behaviors over time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
# The chart reveals the trends in both bookings and cancellations over the years. It highlights which years had higher cancellation rates and which had more successful (non-canceled) bookings. This can help identify patterns, such as years with more volatility or stability in bookings, aiding in understanding the factors that might influence cancellations and successful stays.

# %% [markdown]
# ###19 - Chart

# %%
# Count the number of bookings by country
country_counts = ds['country'].value_counts().reset_index()
country_counts.columns = ['country', 'number_of_bookings']

# Select top 10 countries
top_10_countries = country_counts.head(10)

# Plotting
plt.figure(figsize=(10, 8))
sns.barplot(x='number_of_bookings', y='country', data=top_10_countries, palette='viridis')
plt.xlabel('Number of Bookings')
plt.ylabel('Country')
plt.title('Top 10 Countries by Number of Bookings')
plt.show()
# Out:
# <ipython-input-50-a892a77b9de1>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='number_of_bookings', y='country', data=top_10_countries, palette='viridis')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
# I chose a horizontal bar chart to display the top 10 countries by the number of bookings because it is well-suited for ranking and comparison purposes. This chart type effectively visualizes which countries have the highest number of bookings, making it easy to compare the top contributors.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
# The chart reveals which countries are the top sources of bookings, indicating the primary markets contributing to the hotel's clientele. This information can be valuable for targeted marketing strategies and resource allocation. If certain countries consistently appear at the top, it may suggest a strong presence or brand recognition in those regions.

# %% [markdown]
# ###Chart - 20

# %%
# Count the number of occurrences of each meal type
meal_counts = ds['meal'].value_counts().reset_index()
meal_counts.columns = ['meal', 'count']

# Plotting
plt.figure(figsize=(10, 6))
sns.barplot(x='meal', y='count', data=meal_counts, palette='viridis')
plt.xlabel('Meal Type')
plt.ylabel('Count')
plt.title('Distribution of Meal Types')
plt.show()
# Out:
# <ipython-input-55-ba1bbb0e068e>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='meal', y='count', data=meal_counts, palette='viridis')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
# I chose a bar chart to display the distribution of meal types because it is effective in showing the frequency of each category. This type of chart makes it easy to compare the counts of different meal types and identify which ones are most or least popular among guests.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
# The chart reveals the popularity of different meal types, indicating which meal plans are most commonly chosen by guests. F "BB" (Bed & Breakfast) has the highest count, it suggests that this meal option is the most preferred. Conversely, the least chosen meal types can also be identified, which FB (Full Board).  SC(Self Catering) and HB (Half Board) have lower share then BB but greater then FB.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# - Utilize data-driven insights to optimize pricing strategies and cancellation policies.
#
# - Prioritize customer service enhancements for guests from top countries. Offer multilingual support, cultural sensitivity training, and personalized experiences to improve guest satisfaction.
#
# - Develop dynamic pricing strategies based on lead time distribution. Adjust pricing tiers and availability to maximize revenue from bookings made far in advance or last minute.
#
# - Focus on improving customer retention strategies for segments with higher cancellation rates. Enhance pre-arrival communications, loyalty programs, or personalized offers.
#
# - Tailor marketing efforts and guest communications based on meal preferences. Use guest data to segment audiences and personalize offers, packages, and messaging related to meal options that resonate most with each segment.
#
# - Expand marketing efforts and partnerships in top countries to capitalize on high booking volumes. Strengthen brand presence and customer engagement initiatives in these markets.
#
#
# In summary, the client should focus on leveraging the insights gained from the analysis to implement targeted strategies that enhance customer satisfaction, optimize operational efficiency, and ultimately contribute to achieving the overall business objectives.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# In conclusion, the analysis of hotel booking data has provided valuable insights that can guide strategic decision-making and optimization efforts for the business.
#
#  By understanding the predominant customer segments, hotels can optimize resource allocation, tailor marketing strategies, personalize services, and improve operational efficiency.
#
# These actions will ultimately lead to enhanced guest satisfaction, increased bookings, and a positive impact on the hotel's business performance.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
